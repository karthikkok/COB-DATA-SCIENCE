# %% [markdown]
# ## creating a dataset with pandas

# %%
import pandas as pd

# %%
#Creating a dataframe with lists inside a dict

data= {'company':['skoda','honda','mahindra'],
      'model':['kushaq','civic','thar'],
      'year':[2020,2020,2020],
      'cc':[1498,1799,1997],
       'type':['petrol','petrol','petrol'],
       'price':['20L','20L','16.5L']}
df=pd.DataFrame(data)
df
# Out:
#     company   model  year    cc    type  price
# 0     skoda  kushaq  2020  1498  petrol    20L
# 1     honda   civic  2020  1799  petrol    20L
# 2  mahindra    thar  2020  1997  petrol  16.5L

# %%
#saving the dataframe as 'vehicles.csv' file with no specific index

df.to_csv('vehicles.csv',index=None)

# %%
#loading the data as 'vehicles.csv'

veh=pd.read_csv('/users/bhargavdamarla/1ds_python/vehicles.csv')
veh
# Out:
#     company   model  year    cc    type  price
# 0     skoda  kushaq  2020  1498  petrol    20L
# 1     honda   civic  2020  1799  petrol    20L
# 2  mahindra    thar  2020  1997  petrol  16.5L

# %% [markdown]
# ## creating a dataset using public api

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
df= pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df= pd.json_normalize(data['data'])

# %%
df
# Out:
#          id         name    symbol         slug  num_market_pairs  \
# 0         1      Bitcoin       BTC      bitcoin             10686
# 1      1027     Ethereum       ETH     ethereum              8113
# 2       825  Tether USDt      USDT       tether             69718
# 3      5426       Solana       SOL       solana               563
# 4      1839          BNB       BNB          bnb              1921
# ...     ...          ...       ...          ...               ...
# 4995  19958  Snail Trail     SLIME  snail-trail                 3
# 4996  12895    Lil Floki  LILFLOKI    lil-floki                15
# 4997  28061        SHIB2     SHIB2        shib2                 1
# 4998   5792    Bananatok       BNA    bananatok                 6
# 4999  17429         Puff      PUFF         puff                 7
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2015-02-25T00:00:00.000Z
# 3     2020-04-10T00:00:00.000Z
# 4     2017-07-25T00:00:00.000Z
# ...                        ...
# 4995  2022-05-04T22:43:30.000Z
# 4996  2021-10-19T20:43:11.000Z
# 4997  2023-09-20T04:09:48.000Z
# 4998  2020-07-01T00:00:00.000Z
# 4999  2022-01-18T08:40:44.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3     [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 4     [marketplace, centralized-exchange, payments, ...           NaN
# ...                                                 ...           ...
# 4995       [gaming, avalanche-ecosystem, animal-racing]  3.000000e+08
# 4996                                                 []  1.000000e+15
# 4997                        [memes, ethereum-ecosystem]  1.000000e+09
# 4998                                                 []  2.800000e+09
# 4999                                                 []           NaN
#
#       circulating_supply        total_supply  infinite_supply  platform  \
# 0           1.958144e+07            19581443            False       NaN
# 1           1.201839e+08    120183898.844562             True       NaN
# 2           9.132594e+10  94603058351.448959             True       NaN
# 3           4.288534e+08    565719997.929135             True       NaN
# 4           1.516934e+08    151693443.552291            False       NaN
# ...                  ...                 ...              ...       ...
# 4995        0.000000e+00           300000000            False       NaN
# 4996        0.000000e+00     872876050604093            False       NaN
# 4997        0.000000e+00          1000000000            False       NaN
# 4998        0.000000e+00          1800000000            False       NaN
# 4999        0.000000e+00           420000000            False       NaN
#
#       cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0            1                               NaN                       NaN
# 1            2                               NaN                       NaN
# 2            3                               NaN                       NaN
# 3            4                               NaN                       NaN
# 4            5                               NaN                       NaN
# ...        ...                               ...                       ...
# 4995      4996                      1.162460e+08              7.070726e+05
# 4996      4997                      8.728761e+14              1.880959e+05
# 4997      4998                      1.000000e+09              5.177897e+05
# 4998      4999                      1.800000e+09              1.984101e+06
# 4999      5000                               NaN                       NaN
#
#       tvl_ratio              last_updated  quote.USD.price  \
# 0           NaN  2023-12-26T14:43:00.000Z     4.269184e+04
# 1           NaN  2023-12-26T14:43:00.000Z     2.244316e+03
# 2           NaN  2023-12-26T14:42:00.000Z     9.998596e-01
# 3           NaN  2023-12-26T14:42:00.000Z     1.139295e+02
# 4           NaN  2023-12-26T14:42:00.000Z     3.007975e+02
# ...         ...                       ...              ...
# 4995        NaN  2023-12-26T14:42:00.000Z     6.082552e-03
# 4996        NaN  2023-12-26T14:42:00.000Z     2.154898e-10
# 4997        NaN  2023-12-26T14:42:00.000Z     5.177897e-04
# 4998        NaN  2023-12-26T14:42:00.000Z     1.102279e-03
# 4999        NaN  2023-12-26T14:43:00.000Z     5.872615e-03
#
#       quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0             2.563853e+10                      19.3193
# 1             9.458723e+09                      14.1015
# 2             5.610668e+10                      15.0731
# 3             6.713291e+09                      49.7384
# 4             1.575206e+09                     100.8206
# ...                    ...                          ...
# 4995          4.174311e+03                     -12.6008
# 4996          4.166779e+03                     455.3609
# 4997          4.142220e+03                     -40.2764
# 4998          4.131957e+03                     -13.9100
# 4999          4.109741e+03                      43.6522
#
#       quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                       -0.142748                     -2.257987
# 1                       -0.187151                     -1.971419
# 2                       -0.001340                     -0.037575
# 3                       -1.440143                     -1.606196
# 4                       -0.441487                     12.545254
# ...                           ...                           ...
# 4995                    -2.457986                     -7.937562
# 4996                    -3.216137                     12.026567
# 4997                    14.493705                     21.267474
# 4998                    -0.012637                     -7.301820
# 4999                    -0.407409                      1.494404
#
#       quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                        0.165955                     14.026974
# 1                        1.752879                      8.457403
# 2                        0.040195                     -0.013091
# 3                       53.651546                     99.326629
# 4                       19.806571                     29.515893
# ...                           ...                           ...
# 4995                     9.595867                    128.414393
# 4996                     4.278056                    108.597932
# 4997                    25.736318                     16.205825
# 4998                    -6.799229                     -4.177901
# 4999                    -9.737021                     63.278559
#
#       quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                        25.730710                     62.885641
# 1                        26.136739                     40.492354
# 2                        -0.022507                      0.075346
# 3                       253.440293                    501.032872
# 4                        33.010357                     41.734720
# ...                            ...                           ...
# 4995                    527.181222                    597.398539
# 4996                    253.634768                    405.825001
# 4997                    -49.471088                    -53.257280
# 4998                    -16.975319                    -47.115445
# 4999                    156.203496                    132.711109
#
#       quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0             8.359678e+11                         50.2330
# 1             2.697307e+11                         16.2114
# 2             9.131312e+10                          5.4870
# 3             4.885905e+10                          2.9365
# 4             4.562900e+10                          2.7431
# ...                    ...                             ...
# 4995          0.000000e+00                          0.0000
# 4996          0.000000e+00                          0.0000
# 4997          0.000000e+00                          0.0000
# 4998          0.000000e+00                          0.0000
# 4999          0.000000e+00                          0.0000
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           8.965286e+11            NaN
# 1                           2.697307e+11            NaN
# 2                           9.458978e+10            NaN
# 3                           6.445218e+10            NaN
# 4                           4.562900e+10            NaN
# ...                                  ...            ...
# 4995                        1.824766e+06            NaN
# 4996                        2.154898e+05            NaN
# 4997                        5.177897e+05            NaN
# 4998                        3.086380e+06            NaN
# 4999                        2.466498e+06            NaN
#
#         quote.USD.last_updated  platform.id            platform.name  \
# 0     2023-12-26T14:43:00.000Z          NaN                      NaN
# 1     2023-12-26T14:43:00.000Z          NaN                      NaN
# 2     2023-12-26T14:42:00.000Z       1027.0                 Ethereum
# 3     2023-12-26T14:42:00.000Z          NaN                      NaN
# 4     2023-12-26T14:42:00.000Z          NaN                      NaN
# ...                        ...          ...                      ...
# 4995  2023-12-26T14:42:00.000Z       5805.0        Avalanche C-Chain
# 4996  2023-12-26T14:42:00.000Z       1839.0  BNB Smart Chain (BEP20)
# 4997  2023-12-26T14:42:00.000Z       1027.0                 Ethereum
# 4998  2023-12-26T14:42:00.000Z       1027.0                 Ethereum
# 4999  2023-12-26T14:43:00.000Z       5426.0                   Solana
#
#      platform.symbol platform.slug  \
# 0                NaN           NaN
# 1                NaN           NaN
# 2                ETH      ethereum
# 3                NaN           NaN
# 4                NaN           NaN
# ...              ...           ...
# 4995            AVAX     avalanche
# 4996             BNB           bnb
# 4997             ETH      ethereum
# 4998             ETH      ethereum
# 4999             SOL        solana
#
#                             platform.token_address
# 0                                              NaN
# 1                                              NaN
# 2       0xdac17f958d2ee523a2206206994597c13d831ec7
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 4995    0x5a15Bdcf9a3A8e799fa4381E666466a516F2d9C8
# 4996    0x3271d12d5ba36b6582fafa029598fee0f5f6db35
# 4997    0x2dE7B02Ae3b1f11d51Ca7b2495e9094874A064c0
# 4998    0x20910e5b5f087f6439dfcb0dda4e27d1014ac2b8
# 4999  G9tt98aYSznRk7jWsfuz9FnTdokxS6Brohdo9hSmjTRB
#
# [5000 rows x 36 columns]

# %%
#saving the datafrme as 'coins.csv' file with no index

df.to_csv('coins.csv',index=None)

# %%
coins=pd.read_csv('/users/bhargavdamarla/1ds_python/coins.csv')
coins.head()
# Out:
#      id         name symbol      slug  num_market_pairs  \
# 0     1      Bitcoin    BTC   bitcoin             10686
# 1  1027     Ethereum    ETH  ethereum              8113
# 2   825  Tether USDt   USDT    tether             69718
# 3  5426       Solana    SOL    solana               563
# 4  1839          BNB    BNB       bnb              1921
#
#                  date_added  \
# 0  2010-07-13T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2020-04-10T00:00:00.000Z
# 4  2017-07-25T00:00:00.000Z
#
#                                                 tags  max_supply  \
# 0  ['mineable', 'pow', 'sha-256', 'store-of-value...  21000000.0
# 1  ['pos', 'smart-contracts', 'ethereum-ecosystem...         NaN
# 2  ['payments', 'stablecoin', 'asset-backed-stabl...         NaN
# 3  ['pos', 'platform', 'solana-ecosystem', 'cms-h...         NaN
# 4  ['marketplace', 'centralized-exchange', 'payme...         NaN
#
#    circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0        1.958144e+07  1.958144e+07            False       NaN         1
# 1        1.201839e+08  1.201839e+08             True       NaN         2
# 2        9.132594e+10  9.460306e+10             True       NaN         3
# 3        4.288534e+08  5.657200e+08             True       NaN         4
# 4        1.516934e+08  1.516934e+08            False       NaN         5
#
#    self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                               NaN                       NaN        NaN
# 1                               NaN                       NaN        NaN
# 2                               NaN                       NaN        NaN
# 3                               NaN                       NaN        NaN
# 4                               NaN                       NaN        NaN
#
#                last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0  2023-12-26T14:43:00.000Z     42691.835971          2.563853e+10
# 1  2023-12-26T14:43:00.000Z      2244.316370          9.458723e+09
# 2  2023-12-26T14:42:00.000Z         0.999860          5.610668e+10
# 3  2023-12-26T14:42:00.000Z       113.929470          6.713291e+09
# 4  2023-12-26T14:42:00.000Z       300.797460          1.575206e+09
#
#    quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      19.3193                    -0.142748
# 1                      14.1015                    -0.187151
# 2                      15.0731                    -0.001340
# 3                      49.7384                    -1.440143
# 4                     100.8206                    -0.441487
#
#    quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                     -2.257987                     0.165955
# 1                     -1.971419                     1.752879
# 2                     -0.037575                     0.040195
# 3                     -1.606196                    53.651546
# 4                     12.545254                    19.806571
#
#    quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                     14.026974                     25.730710
# 1                      8.457403                     26.136739
# 2                     -0.013091                     -0.022507
# 3                     99.326629                    253.440293
# 4                     29.515893                     33.010357
#
#    quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     62.885641          8.359678e+11
# 1                     40.492354          2.697307e+11
# 2                      0.075346          9.131312e+10
# 3                    501.032872          4.885905e+10
# 4                     41.734720          4.562900e+10
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         50.2330                        8.965286e+11
# 1                         16.2114                        2.697307e+11
# 2                          5.4870                        9.458978e+10
# 3                          2.9365                        6.445218e+10
# 4                          2.7431                        4.562900e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0            NaN  2023-12-26T14:43:00.000Z          NaN           NaN
# 1            NaN  2023-12-26T14:43:00.000Z          NaN           NaN
# 2            NaN  2023-12-26T14:42:00.000Z       1027.0      Ethereum
# 3            NaN  2023-12-26T14:42:00.000Z          NaN           NaN
# 4            NaN  2023-12-26T14:42:00.000Z          NaN           NaN
#
#   platform.symbol platform.slug                      platform.token_address
# 0             NaN           NaN                                         NaN
# 1             NaN           NaN                                         NaN
# 2             ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN           NaN                                         NaN
# 4             NaN           NaN                                         NaN
